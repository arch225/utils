# %%
import pandas as pd
from faker import Faker
import random

fake = Faker()

def generate_fake_data(num_entries=10):
    data = []

    for _ in range(num_entries):
        entry = {
            "Name": fake.name(),
            "Address": fake.address(),
            "Email": fake.email(),
            "Phone Number": fake.phone_number(),
            "Date of Birth": fake.date_of_birth(minimum_age=18, maximum_age=65).strftime("%Y-%m-%d"),
            "Random Number": random.randint(1, 100),
            "Job Title": fake.job(),
            "Company": fake.company(),
            "Lorem Ipsum Text": fake.text(),
        }
        data.append(entry)

    return pd.DataFrame(data)

if __name__ == "__main__":
    num_entries = 10  # You can adjust the number of entries you want to generate
    fake_data_df = generate_fake_data(num_entries)

    

## Dataframe with Fake Data
fake_data_df
# Out:
#                  Name                                            Address  \
# 0     Stephanie Nunez  102 Parrish Extension Apt. 720\nEast Davidside...
# 1  Melissa Strickland     576 Vega Forges\nSouth Angelicamouth, MT 91695
# 2        Ashley Silva  7156 Williams Ramp Apt. 445\nWest Tyler, GA 06323
# 3     Angela Mcintosh     4730 Vasquez Landing\nGardnerborough, MA 33215
# 4      Maureen Nguyen  4431 Heath Hollow Suite 145\nPort Gregory, VT ...
# 5      Christina Rich       43896 Alvarez Valley\nTiffanyhaven, NC 70241
# 6     Taylor Williams        335 Craig Squares\nCunninghamfort, WI 71761
# 7        Henry Hughes  079 Justin Shore Suite 423\nSouth Andrew, WY 8...
# 8       John Jennings         4564 Angelica Ranch\nPort Lauren, IL 00534
# 9       Sarah Carlson                           USS Powell\nFPO AA 71050
#
#                          Email            Phone Number Date of Birth  \
# 0           fscott@example.org  001-577-809-8754x41151    1993-03-22
# 1            lshaw@example.net   001-324-287-0143x2902    1976-11-14
# 2      angelabrown@example.net              7863813710    1995-04-18
# 3  hendricksstuart@example.com           (644)362-9675    1994-02-16
# 4        hartmindy@example.net           (865)838-3220    2005-05-27
# 5          gmurray@example.net   +1-973-312-0503x13332    1990-10-28
# 6      catherine02@example.net      (686)321-7591x8869    2004-05-29
# 7           fmills@example.com    001-573-565-8089x525    1960-09-15
# 8          mosborn@example.com        001-481-379-3202    1963-05-12
# 9         norman60@example.net        803-816-5072x939    1993-03-06
#
#    Random Number                        Job Title  \
# 0             47    Interior and spatial designer
# 1             96        Insurance account manager
# 2             92               Broadcast engineer
# 3             35            IT sales professional
# 4             89                      Chiropodist
# 5             31        Medical technical officer
# 6             72          Presenter, broadcasting
# 7             89               Facilities manager
# 8             62      Health and safety inspector
# 9              8  Psychotherapist, dance movement
#
#                        Company  \
# 0               Wallace-Garcia
# 1   Bailey, Palmer and Solomon
# 2      Frank, Dixon and Hudson
# 3     Warren, Dunn and Carroll
# 4     Moore, Webb and Jennings
# 5    Huff, Obrien and Williams
# 6                 White-Archer
# 7                Edwards-Moore
# 8             Medina-Daugherty
# 9  Davidson, Ferguson and Lane
#
#                                     Lorem Ipsum Text
# 0  Their despite event outside policy sell deep. ...
# 1  Police him under church establish ok. Agree co...
# 2  Professional entire likely beat leg design wha...
# 3  Wait specific mention during. Smile which cent...
# 4  Recognize lawyer stop knowledge case theory ta...
# 5  Attorney talk catch others. South protect ever...
# 6  Recently establish measure away hot. Different...
# 7  Three personal its feel claim get anyone. Pres...
# 8  Nor themselves first turn loss this guess majo...
# 9  Fire production radio matter. Office science t...
